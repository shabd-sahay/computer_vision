# %% [markdown]
# <a href="https://colab.research.google.com/github/shabd-sahay/computer_vision/blob/main/classwork1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Image Translation using OpenCV**

# %% [markdown]
# **1. import statements**

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %% [markdown]
# **2. import image**

# %%
image = cv2.imread('/content/final.jpg')

# %% [markdown]
# **3. Height, Width and Translation Matrix**

# %%
height, width = image.shape[:2]
quarter_height, quarter_width = height / 4, width / 4

T = np.float32([[1, 0, quarter_width], [0, 1, quarter_height]])

# %% [markdown]
# **4. Image Translation**

# %%
img_translation = cv2.warpAffine(image, T, (width, height))

# %% [markdown]
# **5. Final Output**

# %%
cv2_imshow(image)
cv2_imshow(img_translation)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x1200>
# <PIL.Image.Image image mode=RGB size=1600x1200>

# %%
import numpy as np
import cv2 as cv
from google.colab.patches import cv2_imshow

img = cv.imread('girlImage.png', 0)
rows, cols = img.shape
M = np.float32([[1, 0, 100], [0, 1, 50]])
dst = cv.warpAffine(img, M, (cols, rows))
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=L size=378x287>

# %%
import numpy as np
import cv2 as cv
from google.colab.patches import cv2_imshow

img = cv.imread('girlImage.png', 0)
rows, cols = img.shape
M = np.float32([[1,  0, 0],
                [0, -1, rows],
                [0,  0, 1]])
reflected_img = cv.warpPerspective(img, M,
                                   (int(cols),
                                    int(rows)))
cv2_imshow(reflected_img)
cv.imwrite('reflection_out.jpg', reflected_img)
# Out:
# <PIL.Image.Image image mode=L size=378x287>
# True

# %%
import numpy as np
import cv2 as cv
from google.colab.patches import cv2_imshow

img = cv.imread('/content/girlImage.png', 0)
if img is None:
    print("Error: Image not found or could not be loaded.")
else:
    rows, cols = img.shape
    M = np.float32([[1,  0, 0], [0, -1, rows], [0,  0, 1]])
    img_rotation = cv.warpAffine(img,
                                 cv.getRotationMatrix2D((cols/2, rows/2),
                                                        30, 0.6),
                                 (cols, rows))
    cv2_imshow(img_rotation)
    cv.imwrite('rotation_out.jpg', img_rotation)
# Out:
# <PIL.Image.Image image mode=L size=378x287>

# %%
import numpy as np
import cv2 as cv
from google.colab.patches import cv2_imshow

img = cv.imread('/content/girlImage.png', 0)
rows, cols = img.shape
img_shrinked = cv.resize(img, (250, 200),
                         interpolation=cv.INTER_AREA)
cv2_imshow(img_shrinked)
img_enlarged = cv.resize(img_shrinked, None,
                         fx=1.5, fy=1.5,
                         interpolation=cv.INTER_CUBIC)
cv2_imshow(img_enlarged)
# Out:
# <PIL.Image.Image image mode=L size=250x200>
# <PIL.Image.Image image mode=L size=375x300>

# %%
import numpy as np
import cv2 as cv
from google.colab.patches import cv2_imshow

img = cv.imread('/content/girlImage.png', 0)
if img is None:
    print("Error: Image not found or could not be loaded.")
else:
    cropped_img = img[100:300, 100:300]
    cv.imwrite('cropped_out.jpg', cropped_img)
    cv2_imshow(cropped_img)
# Out:
# <PIL.Image.Image image mode=L size=200x187>

# %%
import numpy as np
import cv2 as cv
from google.colab.patches import cv2_imshow

img = cv.imread('/content/girlImage.png', 0)
if img is None:
    print("Error: Image not found or could not be loaded.")
else:
    rows, cols = img.shape
    M = np.float32([[1, 0.5, 0], [0, 1, 0], [0, 0, 1]])
    sheared_img = cv.warpPerspective(img, M, (int(cols*1.5), int(rows*1.5)))
    cv2_imshow(sheared_img)
# Out:
# <PIL.Image.Image image mode=L size=567x430>

# %%
import numpy as np
import cv2 as cv
from google.colab.patches import cv2_imshow

img = cv.imread('/content/girlImage.png', 0)
if img is None:
    print("Error: Image not found or could not be loaded.")
else:
    rows, cols = img.shape
    M = np.float32([[1,   0, 0], [0.5, 1, 0], [0,   0, 1]])
    sheared_img = cv.warpPerspective(img, M, (int(cols*1.5), int(rows*1.5)))
    cv2_imshow(sheared_img)
# Out:
# <PIL.Image.Image image mode=L size=567x430>
